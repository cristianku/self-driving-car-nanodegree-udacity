# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# prepare object points
nx = 8# enter the number of inside corners in x
ny = 6# enter the number of inside corners in y

objp  = np.zeros((6*8,3), np.float32)
objp[:,:2] = np.mgrid[0:8, 0:6].T.reshape(-1,2)

# %%
import matplotlib.pyplot as plt
import glob
import cv2
import pickle


objpoints =[]
imgpoints =[]
print ( " .. starting  ")
plt.figure(figsize=(20, 20))

plt.subplot(10, 5, 1 )
plt.axis('off')
i = 0
for fname in glob.glob("./calibration_images/*"):
#     print (name)\
    img = cv2.imread(fname)
    
    # Convert to grayscale
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    
    # Find the chessboard corners
    ret, corners = cv2.findChessboardCorners(gray, (nx, ny), None)

    # If found, draw corners
    if ret == True:
        # Draw and display the corners
        cv2.drawChessboardCorners(img, (nx, ny), corners, ret)
        objpoints.append(objp)
        imgpoints.append(corners )


    i += 1
    plt.subplot(10, 5, i )
    plt.axis('off')
    plt.imshow(img)
    

plt.show()

ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, gray.shape[::-1], None, None)


# Save the camera calibration result for later use (we won't worry about rvecs / tvecs)
dist_pickle = {}
dist_pickle["mtx"] = mtx
dist_pickle["dist"] = dist
pickle.dump( dist_pickle, open( "wide_dist_pickle.p", "wb" ) )    
print ( " .. completed ")
# Out:
#  .. starting
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-bfaffdc84144> in <module>()
#      46 dist_pickle["mtx"] = mtx
#      47 dist_pickle["dist"] = dist
# ---> 48 pickle.dump( dist_pickle, open( "calibration_wide/wide_dist_pickle.p", "wb" ) )
#      49 print ( " .. completed ")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'calibration_wide/wide_dist_pickle.p'

# %%
img = cv2.imread("calibration_images/GOPR0032.jpg")
plt.imshow(img)
plt.show()
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

ret, corners = cv2.findChessboardCorners(gray, (8,6),None)

# %%
gray.shape[::-1]
# Out:
# (960, 1280)

# %%
ret, corners = cv2.findChessboardCorners(gray, (8,6),None)

# %%
corners.shape
# Out:
# (48, 1, 2)

# %%
if ret == True:
    imgpoints.append(corners)
    objpoints.append(chess)
    img = cv2.drawChessboardCorners(img,(8,6), corners, ret )
    plt.imshow(img)
plt.show()

# %%
imgpoints
# Out:
# [array([[[  462.56225586,   161.33686829]],
#
#         [[  579.87988281,   169.6980896 ]],
#
#         [[  687.89849854,   184.06251526]],
#
#         [[  782.25585938,   201.73724365]],
#
#         [[  862.12078857,   220.18566895]],
#
#         [[  928.71038818,   238.08705139]],
#
#         [[  984.36712646,   254.63909912]],
#
#         [[ 1030.07141113,   270.04660034]],
#
#         [[  456.55767822,   274.15139771]],
#
#         [[  578.62780762,   278.15264893]],
#
#         [[  690.14172363,   287.34194946]],
#
#         [[  786.54797363,   298.60617065]],
#
#         [[  867.04956055,   310.93722534]],
#
#         [[  934.02697754,   322.45111084]],
#
#         [[  989.10333252,   333.13348389]],
#
#         [[ 1035.05957031,   343.03594971]],
#
#         [[  454.82315063,   397.91821289]],
#
#         [[  578.56787109,   396.97277832]],
#
#         [[  691.44482422,   399.01202393]],
#
#         [[  788.15545654,   402.44265747]],
#
#         [[  869.05108643,   406.34725952]],
#
#         [[  935.97436523,   410.45864868]],
#
#         [[  991.03076172,   414.30374146]],
#
#         [[ 1036.19458008,   418.09417725]],
#
#         [[  458.98831177,   524.48999023]],
#
#         [[  580.9251709 ,   518.86096191]],
#
#         [[  692.23376465,   512.94989014]],
#
#         [[  787.99279785,   507.77999878]],
#
#         [[  868.16143799,   503.22232056]],
#
#         [[  934.68792725,   499.27304077]],
#
#         [[  989.36517334,   496.08883667]],
#
#         [[ 1034.50354004,   493.4569397 ]],
#
#         [[  467.25424194,   643.99377441]],
#
#         [[  584.64190674,   634.03533936]],
#
#         [[  692.00610352,   621.9307251 ]],
#
#         [[  785.84661865,   608.97027588]],
#
#         [[  864.29290771,   596.96337891]],
#
#         [[  929.86883545,   585.75024414]],
#
#         [[  984.16748047,   575.86749268]],
#
#         [[ 1029.22131348,   567.48181152]],
#
#         [[  479.05795288,   749.14050293]],
#
#         [[  589.05621338,   735.91882324]],
#
#         [[  691.03314209,   719.67102051]],
#
#         [[  780.98205566,   701.35394287]],
#
#         [[  857.48327637,   683.63800049]],
#
#         [[  922.18438721,   666.76568604]],
#
#         [[  976.00201416,   651.73248291]],
#
#         [[ 1021.07562256,   637.80499268]]], dtype=float32)]

# %%
img
